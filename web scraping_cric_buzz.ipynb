# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\acer01\appdata\local\programs\python\python39\lib\site-packages (4.10.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer01\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4) (2.3.1)
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\acer01\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\acer01\appdata\local\programs\python\python39\lib\site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer01\appdata\local\programs\python\python39\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\acer01\appdata\local\programs\python\python39\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer01\appdata\local\programs\python\python39\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\acer01\appdata\local\programs\python\python39\lib\site-packages (from requests) (2.0.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\acer01\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
    page=requests.get('https://www.cricbuzz.com/')
    
except Exception as e:
    error_type, error_obj, error_info = sys.exc_info()
    print('ERROR FOR LINK:',url)
    print(error_type,'Line:',error_info.tb_lineno)
    
time.sleep(2)
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en"><head><meta charset="utf-8"/><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}	body, .cb-comm-pg, .cb-hm-mid {min-height:1000px}	.container{width:980px;margin:0 auto;}	.page{max-width: 980px;margin: 0 auto;position: relative;}	.cb-col-8 {width:8%;}	.cb-col-10 {width:10%;}	.cb-col-14 {width:14%;}	.cb-col-16 {width:16%;}	.cb-col-20 {width:20%;}	.cb-col-25 {width:25%;}	.cb-col-27 {width:27%;}	.cb-col-30 {width:30%;}	.cb-col-33 {width:33%;}	.cb-col-40 {width:40%;}	.cb-col-46 {width:46%;}	.cb-col-47 {width:47%;}	.cb-col-50 {width:50%;}	.cb-col-60 {width:60%;}	.cb-col-65 {width:65%;}	.cb-col-66 {width:66%;}	.cb-col-67 {width:67%;}	.cb-col-73 {width:73%;}	.cb-col-75 {width:75%;}	.cb-col-70 {width:70%;}	.cb-col-84 {width:84%;}	.cb-col-80 {width:80%;}	.cb-col-90{width:90%;}	.cb-col-100 {width:100%;}	.cb-col {display: inline-block;box-sizing: border-box;float: left; min-height: 1px;}	h1 {font-size: 36px;line-height: 42px; margin:0;}	h2 {font-size: 24px; margin:0; line-height: 30px;}	h3 {font-size: 18px;line-height: 24px; margin:0; }	h4 {font-size: 16px; margin:0; }	h5 {font-size: 14px; margin: 0;}	.cb-font-18 {font-size:18px;}	img{border-radius: 4px;}	a {text-decoration: none; color:#222;}	a, a:hover, a:active, a:focus {outline: medium none;}	.text-center {text-align: center;}	.cb-nws-lft-col{padding:15px 20px;}	.cb-nws-dtl-lft-col {padding: 10px 30px 0 30px;border-right: 1px solid #ecebeb ;}	.cb-nws-lst-rt{padding-left: 10px;}	.cb-srs-lst-itm {padding: 10px 0;}	.cb-lst-itm-sm{padding:10px 0 5px;}	.cb-scrd-lft-col{padding:15px 10px;} .cb-col-rt{padding: 10px;}	.text-white{color: #fff;}	.cb-scrd-hdr-rw, .cb-nav-pill-1.active {background: #028062 ;color: #fff;}	.cb-nav{position:relative; height:48px;background: #009270;}	.cb-hm-mnu-itm{padding: 16px 6px 11px; color:#fff; display:inline-block;}	.cb-hm-text{padding:10px 18px 10px 20px;}	.cb-hm-rght{padding: 15px;}	.cb-subnav .cb-sub-navigation {display: none; position: absolute;}	.cb-mat-mnu{background:#4a4a4a; width:980px; font-size: 0;}	.cb-mat-mnu-itm{font-size:12px; color:#fff; padding:10px; cursor: pointer; display:inline-block; max-width: 140px;}	.cb-mat-mnu-ttl{background: #333; padding: 10px 20px;}	.cb-mat-mnu-wrp{margin-bottom: 10px;}	.cb-ovr-flo{overflow: hidden; white-space: nowrap; text-overflow: ellipsis;}	.cb-mat-mnu-all{text-align: center; float: right; width:60px;}	.cb-nav-main{border-bottom:1px solid #e3e6e3;padding:0 0 5px 20px;}	.cb-nav-bar{padding-top:10px;clear:both;}	.cb-lst-itm, .cb-bg-white{background: #fff;}	.cb-nav-tab.active, .cb-nav-tab-hm.active{ font-weight: bold; color: #028062;}	.cb-nav-tab.active {border-bottom: 3px solid #028062; line-height: 24px; }	.cb-nav-tab-hm.active{ border-bottom:2px solid #028062; line-height: 22px;}	.cb-nav-tab{margin-right:20px;padding-bottom:6px;}	.cb-nav-tab-hm{margin-right:15px;padding-bottom:6px;}	.cb-nav-hdr{padding-top:15px}	.cb-nav-subhdr{padding:5px 0 10px 0;}	.cb-lv-scr-mtch-hdr{line-height: 21px;font-size: 16px;}	.disp-none{display:none;}	.disp-blck{display:block;}	.cb-font-24{font-size: 24px;}	.line-ht30{line-height: 30px;}	.line-ht24{line-height: 24px;}	.cb-hm-scg-blk{background: #fff; margin-bottom: 5px; height:90px;}	.mrgn-btm-5{margin-bottom : 5px;}	#scagTabContent .show{display: block; visibility: visible;}	#scagTabContent .hide{display: none; visibility: hidden;}	[ng\:cloak], [ng-cloak], [data-ng-cloak], [x-ng-cloak], .ng-cloak, .x-ng-cloak { display: none !important;}	.cb-hm-lft{margin-bottom:5px;padding:0 15px;}	.cb-hm-lft-hdr{margin:0; padding:15px 15px 0; color: #009270;} .cb-hm-mid {border-left: 5px solid #e3e6e3 ;border-rig ...
# .cb-user-itm{position:absolute; top:0; right:5px}</style> </div> </div> <div class="cb-user-itm cb-subnav"> <a href="/premium-subscription/user/account-info" id="cb-plus-user-icon"><span class="cb-plus-ico cb-user-icon"></span></a> <nav class="cb-sub-navigation" id="cb-plus-dropdown" style="right:0px;"> <a class="cb-subnav-item" href="/premium-subscription/user/account-info" target="_self" title="My Account">My Account</a> <a class="cb-subnav-item" ng-click="sign_out_user(false)" target="_self" title="Sign Out">Sign Out</a></nav> </div></nav><style>.cb-text-link{color:#1866db;}
# .cb-plus-menu-button{padding: 8px 14px; background: #fff; border-radius: 18px; border: 0;}
# .cb-plus-menu-button:hover,.cb-plus-menu-button:focus, .cb-plus-menu-button:active{background: #fff;}</style></div></header><div class="page"><div id="fb-root"></div><div class="container" id="page-wrapper" style="display:inline-block;"><div class="ad-unit shosh-embed" id="shosh" style="height:0; width:980px; text-align:center;"></div><span class="ad-unit" id="skin_left" style="overflow:hidden; position:fixed;top:0;left:calc(50% - 635px);margin-right:3px;z-index:-99;"></span><div class="html-refresh" disable-first-load="true" timeout="300000" url="/api/html/matches-menu"><div class="cb-col cb-col-100 mrgn-btm-5"><nav class="cb-mat-mnu" ng-init="direction='up'"><a class="cb-mat-mnu-itm cb-ovr-flo cb-mat-mnu-ttl" href="/cricket-match/live-scores" id="live-scores-link" target="_self" title="">MATCHES</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/41716/isu-vs-psz-24th-match-pakistan-super-league-2022" target="_self" title="Islamabad United v Peshawar Zalmi, 24th Match - Live">ISU vs PSZ - Live</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/38612/ind-vs-wi-2nd-t20i-west-indies-tour-of-india-2022" target="_self" title="India v West Indies, 2nd T20I - Preview">IND vs WI - Preview</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/40543/nz-vs-rsa-1st-test-south-africa-tour-of-new-zealand-2022" target="_self" title="New Zealand v South Africa, 1st Test - Stumps">NZ vs RSA - Stumps</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/40563/nzw-vs-indw-3rd-odi-india-women-tour-of-new-zealand-2022" target="_self" title="New Zealand Women v India Women, 3rd ODI - Preview">NZW vs INDW - Preview</a><a class="cb-mat-mnu-itm cb-ovr-flo" href="/live-cricket-scores/36402/aus-vs-sl-4th-t20i-sri-lanka-tour-of-australia-2022" target="_self" title="Australia v Sri Lanka, 4th T20I - Preview">AUS vs SL - Preview</a><span ng-click="(direction=='up')?direction = 'down' : direction = 'up'"><a class="cb-mat-mnu-itm cb-mat-mnu-all" id="match-dropdown" ng-class="{true:'cb-mat-mnu-cls'}[direction=='down']"><span ng-bind="(direction=='up') ? 'ALL': 'CLOSE'"></span><span ng-class="(direction=='up') ? 'cb-caret-down' : 'cb-caret-up'"></span></a></span></nav><div id="matchmenu"><div class="cb-mm-wrp {{direction}}"><div class="cb-scg-drp-dwn cb-col cb-col-100 cb-mnu-{{direction}}"><nav class="nav cb-mm-nvtb" ng-init="option= 'all'"><a class="cb-nav-pill-2 {{(option=='all')?'active':''}}" ng-click="option='all'" style="margin-right: 20px;">All</a><a class="cb-nav-pill-2 {{(option=='live')?'active':''}}" ng-click="option='live'" style="margin-right: 20px;">Live Now</a><a class="cb-nav-pill-2 {{(option=='today')?'active':''}}" ng-click="option='today'" style="margin-right: 20px;">Today</a></nav><style>.cb-nt-{{option}}{opacity:0.4!important;}</style><ul class="cb-scg-drp-dwn-ul"><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mm-typ">INTERNATIONAL</div><div class="cb-scg-srs-nm">India v West Indies, 2022</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/38607/ind-vs-wi-1st-t20i-india-v-west-indies-2022" target="_self" title="India v West Indies, 1st T20I - IND Won"><span class="cb-mm-mtch-tm">India vs West Indies</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">1st T20I</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/38612/ind-vs-wi-2nd-t20i-india-v-west-indies-2022" target="_self" title="India v West Indies, 2nd T20I - Preview"><span class="cb-mm-mtch-tm">India vs West Indies</span><span class="cb-mm-liv-tag"></span></a><div class="cb-mm-mtch-nm">2nd T20I</div></div></div></li><li class="cb-lst-mtch cb-lst-dom"><div style="display:inline-block"><div class="cb-scg-srs-nm">Australia v Sri Lanka, 2022</div><div class="cb-mtch-all cb-nt-live cb-nt-today"><a href="/live-cricket-scores/36402/ ...
# }</style> <meta content="400" http-equiv="refresh"/> <div class="cb-col cb-col-20"> <div class="cb-bg-white" id="cb-news-blck"><h2 class="cb-hm-lft-hdr cb-lv-scr-mtch-hdr">LATEST NEWS</h2><div class="cb-hm-lft"><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121100/a-pretty-surreal-moment-matt-henry-on-his-record-breaking-7-fer" title="'A pretty surreal moment' - Matt Henry on his record 7-fer">'A pretty surreal moment' - Matt Henry on his record 7-fer</a><div class="cb-nws-time">15m ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121097/worcestershire-sign-azhar-ali-as-matthew-wade-replacement-for-2022-county-championship" title="Worcestershire sign Azhar Ali as Matthew Wade's replacement ">Worcestershire sign Azhar Ali as Matthew Wade's replacement </a><div class="cb-nws-time">2h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121094/keegan-petersen-to-play-for-durham-in-2022-county-season" title="Keegan Petersen to play for Durham in 2022 County season">Keegan Petersen to play for Durham in 2022 County season</a><div class="cb-nws-time">6h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121088/lachlan-henderson-elected-cricket-australia-chair" title="Lachlan Henderson elected Cricket Australia chair">Lachlan Henderson elected Cricket Australia chair</a><div class="cb-nws-time">16h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121086/matt-henry-rattles-south-africa-in-the-morning-session" title="Matt Henry rattles South Africa in the morning session">Matt Henry rattles South Africa in the morning session</a><div class="cb-nws-time">17h ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121082/all-members-of-afghanistan-touring-party-return-negative-tests" title="All members of Afghanistan touring party return negative tests">All members of Afghanistan touring party return negative tests</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121081/shreyas-iyer-named-captain-of-kolkata-knight-riders" title="Shreyas Iyer named captain of Kolkata Knight Riders">Shreyas Iyer named captain of Kolkata Knight Riders</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121080/mark-steketee-replaces-injured-michael-neser-for-pakistan-tests" title="Steketee replaces injured Neser for Pakistan Tests">Steketee replaces injured Neser for Pakistan Tests</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121079/can-mahmudul-hasan-cut-it-in-the-middle-order-in-odis" title="Can Mahmudul Hasan cut it in the middle-order in ODIs?">Can Mahmudul Hasan cut it in the middle-order in ODIs?</a><div class="cb-nws-time">1d ago</div></div><div class="cb-col-100 cb-lst-itm cb-lst-itm-sm"><a class="cb-nws-hdln-ancr text-hvr-underline" href="/cricket-news/121076/pollard-demands-consistency-as-west-indies-aim-to-better-execution" title="Pollard demands consistency as West Indies aim to better execution">Pollard demands consistency as West Indies aim to better execution</a><div class="cb-nws-time">2d ago</div></div><div class="cb-hm-mr-lnk"><a class="cb-font-12 cb-text-link" href="/cricket-news/latest-news" title="More News"><i>More News..</i></a></div></div></div> <div class="cb-bg-white" id="hm-photos-blk"> <h2 class="cb-hm-lft-hdr cb-lv-scr-mtch-hdr">LATEST PHO ...
# });</script> <div class="cb-col cb-hm-mid cb-bg-white cb-hmpage" style="clear:both"> <div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>INDIA VS WI, T20I SERIES</span></div><a href="/cricket-news/121089/the-summer-that-shaped-bishnoi" title="The summer that shaped Bishnoi"><img alt="The summer that shaped Bishnoi" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c226682/the-summer-that-shaped-bishnoi.jpg" title="The summer that shaped Bishnoi" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/121089/the-summer-that-shaped-bishnoi" title="The summer that shaped Bishnoi">	The summer that shaped Bishnoi</a></h2><div class="cb-nws-intr">From playing in the scorching Johdpur heat to donning the Indian jersey, here's the tale of the making of India's newest legspinner</div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/121095/wi-need-answers-against-spin" title="WI need answers against spin"><span class="cb-pretag">2nd T20I preview / </span>WI need answers against spin</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>NZ VS RSA, 1ST TEST</span></div><a href="/live-cricket-scores/40543/nz-vs-rsa-1st-test" title="New Zealand take early lead after Henry's seven-fer"><img alt="New Zealand take early lead after Henry's seven-fer" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c226696/new-zealand-take-early-lead-af.jpg" title="New Zealand take early lead after Henry's seven-fer" width="420"/></a><h2 class="big-crd-hdln"><a href="/live-cricket-scores/40543/nz-vs-rsa-1st-test" title="New Zealand take early lead after Henry's seven-fer">	New Zealand take early lead after Henry's seven-fer</a></h2><div class="cb-nws-intr">Matt Henry picked seven wickets as SA folded for 95 on Day 1 in Christchurch</div><div class="cb-hm-mtch-crd-width cb-lv-scrs-well cb-lv-scrs-well-live"> <a href="/live-cricket-scores/40543/nz-vs-rsa-1st-test-south-africa-tour-of-new-zealand-2022" title="NZ Vs RSA, 1st Test Live cricket scores"> <div class="cb-col cb-col-100 cb-hm-mtch-crd cb-pos-rel"> <div class="cb-scr-wll-chvrn cb-col-90"> <div class="cb-lv-scrs-col text-black"> <div class="cb-col cb-mr-30"> <div class="text-bold">NZ</div> <div class="text-bold">RSA</div> </div> <div class="cb-col"> <div> <span>116-3</span> <span> (39)</span> </div> <div> <span>95</span> </div> </div> </div> <div class="cb-lv-scrs-col cb-text-live" style="white-space:unset;">Day 1: Stumps - New Zealand lead by 21 runs</div> </div> <div class="cb-scr-wll-chvrn cb-col-10"> <div class="cb-ico cb-lv-scr-chvrn-bg"></div> </div> </div> </a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/121091/nz-take-early-lead-after-matt-henry-seven-fer" title="NZ take early lead after Matt Henry seven-fer"><span class="cb-pretag">Report / </span>NZ take early lead after Matt Henry seven-fer</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/121100/a-pretty-surreal-moment-matt-henry-on-his-record-7-fer" title="'A pretty surreal moment' - Matt Henry on his record 7-fer">'A pretty surreal moment' - Matt Henry on his record 7-fer</a></div><div class="big-crd-reltd-itm"><a class="big-crd-rltd-txt" href="/cricket-news/121099/sa-have-chance-to-wake-up-from-nightmare-at-hagley-oval" title="SA have chance to wake up from nightmare at Hagley Oval">SA have chance to wake up from nightmare at Hagley Oval</a></div></div><div class="big-crd-main cb-bg-white cb-pos-rel"><div class="crd-cntxt"><span>NEW ZEALAND WOMEN V INDIA WOMEN, 2022</span></div><a href="/cricket-news/121092/downcast-india-look-to-pull-one-back" title="Downcast India look to pull one back"><img alt="Downcast India look to pull one back" height="235" itemprop="image" src="/a/img/v1/420x235/i1/c226704/downcast-india-look-to-pull-on.jpg" title="Downcast India look to pull one back" width="420"/></a><h2 class="big-crd-hdln"><a href="/cricket-news/121092/d ...

# %%
links
# Out:
# [<div class="cb-nws-intr">From playing in the scorching Johdpur heat to donning the Indian jersey, here's the tale of the making of India's newest legspinner</div>,
#  <div class="cb-nws-intr">Matt Henry picked seven wickets as SA folded for 95 on Day 1 in Christchurch</div>,
#  <div class="cb-nws-intr">The return of Smriti Mandhana, Renuka Singh and Meghana Singh from quarantine should bolster India's chances</div>,
#  <div class="cb-nws-intr">Under-19 World Cup winning skipper Yash Dhull hit a sparkling century on his first-class debut</div>,
#  <div class="cb-nws-intr">The batsman was picked up for INR 12.25 Crore at the recent auction</div>,
#  <div class="cb-nws-intr">A tough choice made after losing his father has put the star pacer's career on a fast track</div>,
#  <div class="cb-nws-intr">Australia have taken a two-nil series-led in the T20I series</div>,
#  <div class="cb-nws-intr">The first day saw a huge demand for pacers and players with IPL experience</div>,
#  <div class="cb-nws-intr">Sri Lanka will play the T20Is first followed by the Tests in Mohali and Bengaluru</div>,
#  <div class="cb-nws-intr">With each team playing just three matches in the group phase, the format affords little room for error</div>,
#  <div class="cb-nws-intr">He takes over from Richard Freudenstein, under whose interim regime Justin Langer and Tim Paine exited from the system</div>,
#  <div class="cb-nws-intr">The South African will be available to play seven County Championship games</div>,
#  <div class="cb-nws-intr">The veteran says considering his recent performances and the 'Test match standard' that he has set, his exclusion from the Test squad for the West Indies tour has hit him hard</div>,
#  <div class="cb-nws-intr">Meanwhile, South Australia pacer Brendan Doggett has been added as a cover in the Test squad</div>,
#  <div class="cb-nws-intr">The youngster has taken to the opening spot in Tests but will now be shunted to No.5 in the 50-over format</div>,
#  <div class="cb-nws-intr">Skipper Mohammad Rizwan top-scored with 76 in the successful chase</div>,
#  <div class="cb-nws-intr">Only two days after earning a whopping INR 8.25 Crore contract in the IPL Auction, Tim David has re-signed with Hobart Hurricanes on a two-year contract</div>,
#  <div class="cb-nws-intr">Meanwhile, Nepal fumbled in a modest chase after restricting Ireland to just 127</div>,
#  <div class="cb-nws-intr">In an exclusive interview, former COO of the league Sundar Raman discusses the IPL auction, how it was conceived and whether it has outlived its usefulness</div>,
#  <div class="cb-nws-intr">The middle-order batter had announced his retirement after failing to make the cut for the 2019 World Cup, but turned a new page in his career thereafter</div>,
#  <div class="cb-nws-intr">With 40 wins as captain, Virat Kohli is India's most successful Test captain </div>,
#  <div class="cb-nws-intr">Few people seem willing to talk about how the current transformation policies are affecting the players in South Africa's cricket systems</div>,
#  <div class="cb-nws-intr">The people behind the rise of KKR's newest star shed light on a calm-headed boy and a batting powerhouse</div>,
#  <div class="cb-nws-intr">Perpetually caught in the afterglow of a star pack, van der Dussen finally gets his moment in the sun</div>,
#  <div class="cb-nws-intr">The contrasting fortunes of Joe Root and Virat Kohli in the ongoing series have reminded us of the ebb and flow of greatness as well as the way we crave it, writes Jon Hotten in a new column for Cricbuzz Plus</div>,
#  <div class="cb-nws-intr">Navid Nawaz explains his team's preparations and plans as they look to defend the Under-19 World Cup title</div>]

# %%
for i in links:
    print(i.text)
    print('\n')
# Out:
# From playing in the scorching Johdpur heat to donning the Indian jersey, here's the tale of the making of India's newest legspinner
#
#
# Matt Henry picked seven wickets as SA folded for 95 on Day 1 in Christchurch
#
#
# The return of Smriti Mandhana, Renuka Singh and Meghana Singh from quarantine should bolster India's chances
#
#
# Under-19 World Cup winning skipper Yash Dhull hit a sparkling century on his first-class debut
#
#
# The batsman was picked up for INR 12.25 Crore at the recent auction
#
#
# A tough choice made after losing his father has put the star pacer's career on a fast track
#
#
# Australia have taken a two-nil series-led in the T20I series
#
#
# The first day saw a huge demand for pacers and players with IPL experience
#
#
# Sri Lanka will play the T20Is first followed by the Tests in Mohali and Bengaluru
#
#
# With each team playing just three matches in the group phase, the format affords little room for error
#
#
# He takes over from Richard Freudenstein, under whose interim regime Justin Langer and Tim Paine exited from the system
#
#
# The South African will be available to play seven County Championship games
#
#
# The veteran says considering his recent performances and the 'Test match standard' that he has set, his exclusion from the Test squad for the West Indies tour has hit him hard
#
#
# Meanwhile, South Australia pacer Brendan Doggett has been added as a cover in the Test squad
#
#
# The youngster has taken to the opening spot in Tests but will now be shunted to No.5 in the 50-over format
#
#
# Skipper Mohammad Rizwan top-scored with 76 in the successful chase
#
#
# Only two days after earning a whopping INR 8.25 Crore contract in the IPL Auction, Tim David has re-signed with Hobart Hurricanes on a two-year contract
#
#
# Meanwhile, Nepal fumbled in a modest chase after restricting Ireland to just 127
#
#
# In an exclusive interview, former COO of the league Sundar Raman discusses the IPL auction, how it was conceived and whether it has outlived its usefulness
#
#
# The middle-order batter had announced his retirement after failing to make the cut for the 2019 World Cup, but turned a new page in his career thereafter
#
#
# With 40 wins as captain, Virat Kohli is India's most successful Test captain
#
#
# Few people seem willing to talk about how the current transformation policies are affecting the players in South Africa's cricket systems
#
#
# The people behind the rise of KKR's newest star shed light on a calm-headed boy and a batting powerhouse
#
#
# Perpetually caught in the afterglow of a star pack, van der Dussen finally gets his moment in the sun
#
#
# The contrasting fortunes of Joe Root and Virat Kohli in the ongoing series have reminded us of the ebb and flow of greatness as well as the way we crave it, writes Jon Hotten in a new column for Cricbuzz Plus
#
#
# Navid Nawaz explains his team's preparations and plans as they look to defend the Under-19 World Cup title
